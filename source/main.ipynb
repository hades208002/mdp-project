# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Introduction" data-toc-modified-id="Introduction-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Introduction</a></span><ul class="toc-item"><li><span><a href="#Project-Members" data-toc-modified-id="Project-Members-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Project Members</a></span></li><li><span><a href="#Libraries" data-toc-modified-id="Libraries-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Libraries</a></span></li></ul></li><li><span><a href="#Data" data-toc-modified-id="Data-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Data</a></span><ul class="toc-item"><li><span><a href="#Details" data-toc-modified-id="Details-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Details</a></span></li><li><span><a href="#Preparation" data-toc-modified-id="Preparation-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Preparation</a></span></li><li><span><a href="#Statistical-Analysis" data-toc-modified-id="Statistical-Analysis-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Statistical Analysis</a></span><ul class="toc-item"><li><span><a href="#Quick-Look" data-toc-modified-id="Quick-Look-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Quick Look</a></span></li><li><span><a href="#Non-Missing-Attribute-Details" data-toc-modified-id="Non-Missing-Attribute-Details-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>Non-Missing Attribute Details</a></span><ul class="toc-item"><li><span><a href="#Patsex" data-toc-modified-id="Patsex-2.3.2.1"><span class="toc-item-num">2.3.2.1&nbsp;&nbsp;</span>Patsex</a></span></li><li><span><a href="#AFclass" data-toc-modified-id="AFclass-2.3.2.2"><span class="toc-item-num">2.3.2.2&nbsp;&nbsp;</span>AFclass</a></span></li><li><span><a href="#Age" data-toc-modified-id="Age-2.3.2.3"><span class="toc-item-num">2.3.2.3&nbsp;&nbsp;</span>Age</a></span></li><li><span><a href="#IPG" data-toc-modified-id="IPG-2.3.2.4"><span class="toc-item-num">2.3.2.4&nbsp;&nbsp;</span>IPG</a></span></li></ul></li></ul></li><li><span><a href="#Handling-Missing-Values" data-toc-modified-id="Handling-Missing-Values-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Handling Missing Values</a></span><ul class="toc-item"><li><span><a href="#Quick-Look" data-toc-modified-id="Quick-Look-2.4.1"><span class="toc-item-num">2.4.1&nbsp;&nbsp;</span>Quick Look</a></span><ul class="toc-item"><li><span><a href="#Missing-Values-Count" data-toc-modified-id="Missing-Values-Count-2.4.1.1"><span class="toc-item-num">2.4.1.1&nbsp;&nbsp;</span>Missing Values Count</a></span></li><li><span><a href="#Correlation-Heatmap-for-Missing-Values" data-toc-modified-id="Correlation-Heatmap-for-Missing-Values-2.4.1.2"><span class="toc-item-num">2.4.1.2&nbsp;&nbsp;</span>Correlation Heatmap for Missing Values</a></span></li><li><span><a href="#Dendrogram" data-toc-modified-id="Dendrogram-2.4.1.3"><span class="toc-item-num">2.4.1.3&nbsp;&nbsp;</span>Dendrogram</a></span></li></ul></li><li><span><a href="#Missing-Attribute-Details" data-toc-modified-id="Missing-Attribute-Details-2.4.2"><span class="toc-item-num">2.4.2&nbsp;&nbsp;</span>Missing Attribute Details</a></span><ul class="toc-item"><li><span><a href="#IPG,-RR-and-QR" data-toc-modified-id="IPG,-RR-and-QR-2.4.2.1"><span class="toc-item-num">2.4.2.1&nbsp;&nbsp;</span>IPG, RR and QR</a></span></li><li><span><a href="#QTm_old-and-QTn" data-toc-modified-id="QTm_old-and-QTn-2.4.2.2"><span class="toc-item-num">2.4.2.2&nbsp;&nbsp;</span>QTm_old and QTn</a></span></li><li><span><a href="#Pdur" data-toc-modified-id="Pdur-2.4.2.3"><span class="toc-item-num">2.4.2.3&nbsp;&nbsp;</span>Pdur</a></span></li><li><span><a href="#Parea" data-toc-modified-id="Parea-2.4.2.4"><span class="toc-item-num">2.4.2.4&nbsp;&nbsp;</span>Parea</a></span></li><li><span><a href="#Pfwhm" data-toc-modified-id="Pfwhm-2.4.2.5"><span class="toc-item-num">2.4.2.5&nbsp;&nbsp;</span>Pfwhm</a></span></li><li><span><a href="#QRS-,-PQ-and-P_LoffEon" data-toc-modified-id="QRS-,-PQ-and-P_LoffEon-2.4.2.6"><span class="toc-item-num">2.4.2.6&nbsp;&nbsp;</span>QRS , PQ and P_LoffEon</a></span></li></ul></li><li><span><a href="#Imputing" data-toc-modified-id="Imputing-2.4.3"><span class="toc-item-num">2.4.3&nbsp;&nbsp;</span>Imputing</a></span><ul class="toc-item"><li><span><a href="#Mean-and-Zero-Based-Strategy" data-toc-modified-id="Mean-and-Zero-Based-Strategy-2.4.3.1"><span class="toc-item-num">2.4.3.1&nbsp;&nbsp;</span>Mean and Zero Based Strategy</a></span></li><li><span><a href="#Clear-and-Fancy-Impute-Strategy" data-toc-modified-id="Clear-and-Fancy-Impute-Strategy-2.4.3.2"><span class="toc-item-num">2.4.3.2&nbsp;&nbsp;</span>Clear and Fancy Impute Strategy</a></span></li></ul></li><li><span><a href="#Testing" data-toc-modified-id="Testing-2.4.4"><span class="toc-item-num">2.4.4&nbsp;&nbsp;</span>Testing</a></span><ul class="toc-item"><li><span><a href="#Simple-Single-Methods" data-toc-modified-id="Simple-Single-Methods-2.4.4.1"><span class="toc-item-num">2.4.4.1&nbsp;&nbsp;</span>Simple Single Methods</a></span></li><li><span><a href="#Cross-validation-and-ROC-curve-method" data-toc-modified-id="Cross-validation-and-ROC-curve-method-2.4.4.2"><span class="toc-item-num">2.4.4.2&nbsp;&nbsp;</span>Cross validation and ROC curve method</a></span></li><li><span><a href="#Partial-Dependence-Plot" data-toc-modified-id="Partial-Dependence-Plot-2.4.4.3"><span class="toc-item-num">2.4.4.3&nbsp;&nbsp;</span>Partial Dependence Plot</a></span></li><li><span><a href="#Feature-Elimination/Selection" data-toc-modified-id="Feature-Elimination/Selection-2.4.4.4"><span class="toc-item-num">2.4.4.4&nbsp;&nbsp;</span>Feature Elimination/Selection</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#References" data-toc-modified-id="References-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>References</a></span></li></ul></div>

# %% [markdown]
# # Introduction

# %% [markdown]
# This notebook contains the full pipeline of data processing and visualization.

# %% [markdown]
# ## Project Members

# %% [markdown]
# - GIOVANNI PELOSI
# - SHUWEN KANG
# - MELISA ALTINSOY
# - REFIK MALLI
# - VANESSA GAO

# %% [markdown]
# ## Libraries

# %%
import numpy as np
from scipy import interp
import pandas as pd
from pandas_summary import DataFrameSummary
from matplotlib import pyplot as plt
import missingno as msno
import seaborn as sns
# from matplotlib_venn import venn3,venn2
from sklearn_pandas import CategoricalImputer
from sklearn_pandas import gen_features
from sklearn_pandas import DataFrameMapper, cross_val_score
from sklearn.preprocessing import Imputer,StandardScaler,LabelEncoder
from sklearn.model_selection import cross_val_score
from sklearn import svm
from sklearn.manifold import TSNE
from sklearn.metrics import roc_curve, auc
from sklearn import model_selection
from fancyimpute import BiScaler, KNN, NuclearNormMinimization, SoftImpute, MICE
from sklearn.model_selection import StratifiedKFold
from sklearn.feature_selection import RFECV

# %matplotlib inline
pd.set_option('display.max_columns',500)
pd.set_option('display.max_rows',500)
# Out:
# /Users/refikcanmalli/anaconda3/envs/vodafone/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# # Data
#
# The dataset contains the information collected from Atrial Fibrallition patients.

# %% [markdown]
# ## Details
#
# - All the meanings of the columns are given below
#
# -  PCNeg has several missing values because the PCA  is performed so that (in general) there is no negative component (so PCNeg is set to NaN). However when the behavior is biphasic, this is not the case and PCNeg has a defined value
#
# - When IPG is 1, it means that pacemaker influenced the reading. Thus, it is set to NaN any value that was influenced and was not a physiological response of the patient (otherwise values would be a measure of the pacemaker parameters).
#
#
#
# ![Dataset Columns Information](../data/datainfo.png)

# %% [markdown]
# ## Preparation

# %% [markdown]
# 1. Open the "data.mat" file in MATLAB
# 1. Export each table to csv file with `writetable(tablename,filename)` function.
# 1. Open csv files with pandas and merge them into one file.

# %%
df_pers = pd.read_csv('../data/pers.csv')
df_parox = pd.read_csv('../data/parox.csv')
together = [df_pers, df_parox]
full = pd.concat(together)
full.sample(5)
full.to_pickle('../data/data.pickle')

# %% [markdown]
# ## Statistical Analysis

# %%
df = pd.read_pickle('../data/data.pickle')
df.to_csv("../data/fulldata.csv",encoding='utf-8', index=False)
# Alias for the data name
data = df
print("Sample Number :", len(data))
print("Column Number :", len(data.iloc[0]))
# Out:
# Sample Number : 1100
# Column Number : 73

# %%
import pandas_profiling
profile = pandas_profiling.ProfileReport(df)
profile.to_file(outputfile="/Users/refikcanmalli/Desktop/myoutputfile_mdp.html")
# Out:
# /Users/refikcanmalli/anaconda3/envs/vodafone/lib/python3.6/site-packages/pandas_profiling/plot.py:15: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/Users/refikcanmalli/anaconda3/envs/vodafone/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/refikcanmalli/anaconda3/envs/vodafone/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/refikcanmalli/anaconda3/envs/vodafone/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
# ...

# %% [markdown]
# ### Quick Look

# %%
df.describe()
# Out:
#                 RR      QTm_old  sbjBeatConsidered  numRRaveraged  \
# count  1088.000000  1081.000000        1100.000000    1100.000000
# mean   1001.817699   393.759482         281.322727     272.390909
# std     159.111933    39.409830          54.766644      60.132247
# min     561.991435   296.000000          90.000000      10.000000
# 25%     886.250081   366.000000         246.000000     237.000000
# 50%     993.917866   389.000000         279.000000     271.000000
# 75%    1106.487719   417.000000         316.000000     312.000000
# max    1637.610738   567.000000         483.000000     480.000000
#
#                 QR          QTn          QRS          IPG           PQ  \
# count  1088.000000  1081.000000  1038.000000  1100.000000  1029.000000
# mean     34.939338   394.680826    77.616570     0.010909   188.064140
# std       9.984440    28.009183    15.768314     0.103923    35.749612
# min      16.000000   319.472631    50.000000     0.000000    72.000000
# ...

# %%
df_summary = DataFrameSummary(df)

# %%
df_summary.columns_types
# Out:
# numeric    69
# bool        3
# unique      1
# Name: types, dtype: int64

# %%
df_summary.columns_stats
# Out:
#              Soggetti       RR  QTm_old sbjBeatConsidered numRRaveraged  \
# counts           1100     1088     1081              1100          1100
# uniques          1100     1088      188               247           270
# missing             0       12       19                 0             0
# missing_perc       0%    1.09%    1.73%                0%            0%
# types          unique  numeric  numeric           numeric       numeric
#
#                    QR      QTn      QRS   IPG       PQ    PCpos    PCneg  \
# counts           1088     1081     1038  1100     1029     1039      249
# uniques            55     1081       85     2      175     1039      249
# missing            12       19       62     0       71       61      851
# missing_perc    1.09%    1.73%    5.64%    0%    6.45%    5.55%   77.36%
# types         numeric  numeric  numeric  bool  numeric  numeric  numeric
#
#                 PCdur   PCfwhm   PCarea P_LoffEon Pdur16mean Pdur16median  \
# ...

# %%
corr = df.corr()
plt.figure(figsize = (16,16))
sns.heatmap(corr,
        xticklabels=corr.columns,
        yticklabels=corr.columns);

# %% [markdown]
# ### Non-Missing Attribute Details

# %% [markdown]
# #### Patsex

# %%
df_summary['patsex']
# Out:
# "männlich" count       760
# "männlich" perc     69.09%
# "weiblich" count       340
# "weiblich" perc     30.91%
# counts                1100
# uniques                  2
# missing                  0
# missing_perc            0%
# types                 bool
# Name: patsex, dtype: object

# %%
patsex = list(df.patsex)

# %%
# Count for each gender
num_male = patsex.count('männlich')
num_female = patsex.count('weiblich')

# %%
# Plot gender distribution   
labels=['male','female']  
X=[num_male, num_female]    
    
plt.pie(X,labels=labels,autopct='%1.2f%%')  
plt.title("Pie Chart of Gender")
# Out:
# Text(0.5,1,'Pie Chart of Gender')

# %% [markdown]
# #### AFclass

# %%
df_summary['AFclass']
# Out:
# "paroxysmal" count                       748
# "paroxysmal" perc                        68%
# "persistierend (>7 Tage, EKV)" count     352
# "persistierend (>7 Tage, EKV)" perc      32%
# counts                                  1100
# uniques                                    2
# missing                                    0
# missing_perc                              0%
# types                                   bool
# Name: AFclass, dtype: object

# %%
# plot class distribution
AFclass = list(df.AFclass)
num_par = AFclass.count('paroxysmal')
num_per = AFclass.count('persistierend (>7 Tage, EKV)')

labels=['paroxysmal','persistierend (>7 Tage, EKV)']  
X=[num_par, num_per]    
    
plt.pie(X,labels=labels,autopct='%1.2f%%');
plt.title("Pie Chart of Class");

# %%
par_male = df[(df['patsex']=='männlich')&(df['AFclass']=='paroxysmal')]
par_female = df[(df['patsex']=='weiblich')&(df['AFclass']=='paroxysmal')]
per_male = df[(df['patsex']=='männlich')&(df['AFclass']=='persistierend (>7 Tage, EKV)')]
per_female = df[(df['patsex']=='weiblich')&(df['AFclass']=='persistierend (>7 Tage, EKV)')]

# plot class and gender distribution
labels=['paroxysmal_male', 'paroxysmal_male_female', 'persistierend_male', 'persistierend_female']  
X=[len(par_male), len(par_female), len(per_male), len(per_female)]    

wedgeprops = {'linewidth':2, 'edgecolor':'white' }
plt.pie(X,labels=labels,autopct='%1.2f%%',colors=['tab:blue','tab:blue','tab:orange','tab:orange'],wedgeprops=wedgeprops) #画饼图（数据，数据对应的标签，百分数保留两位小数点）  
plt.title("Pie Chart of Class and Gender")
# Out:
# Text(0.5,1,'Pie Chart of Class and Gender')

# %% [markdown]
# #### Age

# %%
# There are 49 age groups, let's see the Age Distribution.
Age = list(df.Age)
len(set(Age))
age_dict = {}
for age in set(Age):
    age_dict[age] = Age.count(age)

fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(1,1,1)
ax.set_title('Age Distribution', fontsize = 20)
ax.set_xlabel('Age', fontsize = 15)
ax.set_ylabel('Number of Patients', fontsize = 15)
plt.xticks(range(len(age_dict)), list(age_dict.keys()))
plt.bar(range(len(age_dict)), age_dict.values(), align="center")
ax.grid()

# %%
# How about the gender distribution within each age group?   {'männlich', 'weiblich'}
age_male = df[df['patsex'] == 'männlich']
age_female = df[df['patsex'] == 'weiblich']
male_age_dict = {}
female_age_dict = {}
for age in Age:
    male_age_dict[age] = len(age_male[age_male['Age']==age])
    female_age_dict[age] = len(age_female[age_female['Age']==age])

fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(1,1,1)
ax.set_title('Age Distribution', fontsize = 20)
ax.set_xlabel('Age', fontsize = 15)
ax.set_ylabel('Number of Patients', fontsize = 15)
plt.xticks(range(len(male_age_dict)), list(male_age_dict.keys()))
plt.bar(range(len(male_age_dict)), list(male_age_dict.values()), align="center", label='male')
plt.bar(range(len(female_age_dict)), list(female_age_dict.values()), bottom=list(male_age_dict.values()), align="center", label='female')
plt.legend(fontsize = 'x-large')
ax.grid()

# %%
# How about also consider the disease class?   {'paroxysmal', 'persistierend (>7 Tage, EKV)'}
age_male_par = df[(df['patsex'] == 'männlich')&(df['AFclass'] == 'paroxysmal')]
age_female_par = df[(df['patsex'] == 'weiblich')&(df['AFclass'] == 'paroxysmal')]
age_male_per = df[(df['patsex'] == 'männlich')&(df['AFclass'] == 'persistierend (>7 Tage, EKV)')]
age_female_per = df[(df['patsex'] == 'weiblich')&(df['AFclass'] == 'persistierend (>7 Tage, EKV)')]
male_par_age_dict = {}
female_par_age_dict = {}
male_per_age_dict = {}
female_per_age_dict = {}
for age in Age:
    male_par_age_dict[age] = len(age_male_par[age_male_par['Age']==age])
    female_par_age_dict[age] = len(age_female_par[age_female_par['Age']==age])
    male_per_age_dict[age] = len(age_male_per[age_male_per['Age']==age])
    female_per_age_dict[age] = len(age_female_per[age_female_per['Age']==age])

m_par = list(male_par_age_dict.values())
f_par = list(female_par_age_dict.values())
m_per = list(male_per_age_dict.values())
f_per = list(female_per_age_dict.values())
    
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(1,1,1)
ax.set_title('Age Distribution', fontsize = 20)
ax.set_xlabel('Age', fontsize = 15)
ax.set_ylabel('Number of Patients', fontsize = 15)
plt.xticks(range(len(male_par_age_dict)), list(male_par_age_dict.keys()))
plt.bar(range(len(male_par_age_dict)), m_par, align="center", label='male_paroxysmal')
plt.bar(range(len(male_par_age_dict)), m_per, align="center", label='male_persistierend', bottom=m_par, color='blue')

plt.legend(fontsize = 'x-large')
ax.grid()

# %%
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(1,1,1)
ax.set_title('Age Distribution', fontsize = 20)
ax.set_xlabel('Age', fontsize = 15)
ax.set_ylabel('Number of Patients', fontsize = 15)
plt.xticks(range(len(male_par_age_dict)), list(male_par_age_dict.keys()))
plt.bar(range(len(male_par_age_dict)), f_par, align="center", label='female_paroxysmal', color='tab:orange')
plt.bar(range(len(male_par_age_dict)), f_per, align="center", label='female_persistierend', bottom=f_par, color='y')

plt.legend(fontsize = 'x-large')
ax.grid()

# %% [markdown]
# #### IPG

# %%
IPG = list(data.IPG)
num_0 = IPG.count(0)
num_1 = IPG.count(1)

# %%
# plot IPG distribution
labels=['IPG_0','IPG_1']  
X=[num_0, num_1]    
    
plt.pie(X,labels=labels,autopct='%1.2f%%');  
plt.title("Pie Chart of IPG");

# %% [markdown]
# ## Handling Missing Values

# %% [markdown]
# 1. **Missing Completely at Random (MCAR):** This means that the nature of the missing data is not related to any of the variables, whether missing or observed. In this case, the missingness on the variable is completely unsystematic.
#
# 2. **Missing at Random (MAR):** This means that the nature of the missing data is related to the observed data but not the missing data.
#
# 3. **Missing Not at Random (MNAR):** This is also known as non-ignorable because the missingness mechanism cannot be ignored. They exist when the missing values are neither MCAR or MAR. The missing values on the variable are related to that of both the observed and unobserved variables.The difficulty with MNAR data is intrinsically associated with the issue of identifiability.

# %% [markdown]
# ### Quick Look

# %% [markdown]
# #### Missing Values Count

# %%
num_missing = data.shape[0] - data.count()
num_missing.plot(kind='bar', figsize=(17,10), title='Missing Data', ylim=(0,1100));

# %% [markdown]
# #### Correlation Heatmap for Missing Values

# %% [markdown]
# This map describes the degree of nullity relationship between the different features. The range of this nullity correlation is from -1 to 1 (-1 ≤ R ≤ 1). Features with no missing value are excluded in the heatmap. If the nullity correlation is very close to zero (-0.05 < R < 0.05), no value will be displayed. Also, a perfect positive nullity correlation (R=1) indicates when the first feature and the second feature both have corresponding missing values while a perfect negative nullity correlation (R=-1) means that one of the features is missing and the second is not missing.
#
# - Nullity correlation ranges from `-1` (if one variable appears the other definitely does not) to `0` (variables appearing or not appearing have no effect on one another) to `1` (if one variable appears the other definitely also does).
# - Variables that are always full or always empty have no meaningful correlation, and so are silently removed from the visualization.
# - Entries marked `< 1` or `> -1` are have a correlation that is close to being exactingly negative or positive, but is still not quite perfectly so. This points to a small number of records in the dataset which are erroneous.

# %%
msno.heatmap(df, figsize=(35,35));

# %% [markdown]
# #### Dendrogram
#
# To interpret this graph, read it from a top-down perspective. Cluster leaves which linked together at a distance of zero fully predict one another's presence—one variable might always be empty when another is filled, or they might always both be filled or both empty, and so on. In this specific example the dendrogram glues together the variables which are required and therefore present in every record.
#
# Cluster leaves which split close to zero, but not at it, predict one another very well, but still imperfectly. If your own interpretation of the dataset is that these columns actually are or ought to be match each other in nullity,then the height of the cluster leaf tells you, in absolute terms, how often the records are "mismatched" or incorrectly filed—that is, how many values you would have to fill in or drop, if you are so inclined.

# %%
msno.dendrogram(df);

# %% [markdown]
# ### Missing Attribute Details

# %% [markdown]
# #### IPG, RR and QR

# %% [markdown]
# - It is easy to find out that there are 12 "ill" data in column 'IPG', which are consistent with the missing data in column 'RR' and 'QR', thus, if we drop these 12 rows, we can handle the data missing problem for 'RR' and 'QR'. Notice that after dropping 12 rows, 'IPG' is no longer a significant feature.
#
# - Or, we can drop this column and fill 'QR' 'RR'.

# %%
# just for checking the missing data in column 'RR' and 'QR'
IPG = set(data[data['IPG']==1].Soggetti)
QR = set(data[data['QR'].isnull()].Soggetti)
RR = set(data[data['RR'].isnull()].Soggetti)

prindata[data['RR'].isnull()].Soggetti

plt.figure(figsize=(4, 4))
venn3([IPG,QR,RR], set_labels=['IPG','QR','RR'])
plt.show();

# %% [markdown]
# #### QTm_old and QTn

# %%
QTm_old = set(data[data['QTm_old'].isnull()].Soggetti)
QTn = set(data[data['QTn'].isnull()].Soggetti)
plt.figure(figsize=(4, 4))
venn2([QTm_old, QTn], set_labels=['QTm_old','QTn'])
plt.show()
print(QTm_old)
print(QTn)
# Out:
# {'01_2340', '01_2568', '11_0006', '11_0098', '11_0311', '12_0092', '01_2039', '01_2093', '10_0039', '12_0039', '15_0197', '01_2255', '12_0129', '15_0085', '01_2433', '01_2486', '15_0276', '11_0282', '10_0123'}
# {'01_2340', '01_2568', '11_0006', '11_0098', '11_0311', '12_0092', '01_2039', '01_2093', '10_0039', '12_0039', '15_0197', '01_2255', '12_0129', '15_0085', '01_2433', '01_2486', '15_0276', '11_0282', '10_0123'}

# %%
plt.figure(figsize=(4, 4))
venn2([IPG,QTn], set_labels=['IPG','QTn'])
plt.show()
print(QTn - IPG)
# Out:
# {'01_2340', '01_2568', '11_0006', '11_0098', '10_0039', '12_0039', '11_0282'}

# %% [markdown]
# - Another 7 "ill" rows found. We should drop these seven rows or at least drop 4 of them.

# %% [markdown]
# #### Pdur

# %%
df_columns = df.columns.tolist()
matching_columns = [s for s in df_columns if "Pdur" in s]
df_selected = data[matching_columns]
df_selected.head()
# Out:
#    Pdur16mean  Pdur16median  Pdur16min  Pdur16max  Pdur16std  Pdur16iqr  \
# 0    116.7500         122.0      103.0      127.0   8.590693       15.0
# 1    122.5000         122.5      118.0      129.0   3.326660        4.0
# 2     83.8125          83.5       76.0       99.0   5.833452        8.5
# 3    133.4375         135.5      119.0      143.0   6.632936       10.0
# 4    145.8750         141.0      126.0      165.0  12.483990       22.5
#
#    Pdur_ECG_I  Pdur_ECG_II  Pdur_ECG_III  Pdur_ECG_V1  Pdur_ECG_V2  \
# 0       127.0        122.0         123.0        103.0        104.0
# 1       120.0        123.0         122.0        129.0        125.0
# 2        81.0         84.0          85.0         88.0         89.0
# 3       135.0        135.0         136.0        126.0        125.0
# 4       137.0        160.0         148.0        136.0        137.0
#
#    Pdur_ECG_V3  Pdur_ECG_V3R  Pdur_ECG_V4  Pdur_ECG_V4R  Pdur_ECG_V5  \
# ...

# %%
msno.heatmap(df_selected, figsize=(10,10));

# %%
del df_selected, df_columns, matching_columns

# %% [markdown]
# #### Parea

# %%
df_columns = df.columns.tolist()
matching_columns = [s for s in df_columns if "Parea" in s]
df_selected = data[matching_columns]
df_selected.head()
# Out:
#    Parea_ECG_I  Parea_ECG_II  Parea_ECG_III  Parea_ECG_V1  Parea_ECG_V2  \
# 0     263.0136      5362.682       5708.737      2273.143      1696.737
# 1    4532.1150      5892.711       1651.906      3547.616      4571.468
# 2    1174.2350      1239.271       1051.392      1333.991      3042.095
# 3    4212.6670      8970.183       4467.621      2235.111      1111.535
# 4     414.9699      5722.688       5873.872      5250.664      3234.833
#
#    Parea_ECG_V3  Parea_ECG_V3R  Parea_ECG_V4  Parea_ECG_V4R  Parea_ECG_V5  \
# 0      2135.829       4283.591      1851.163       4407.373      1380.435
# 1      4837.418       2817.351      4680.697       2087.393      4258.456
# 2      3178.096       1409.781      2454.455       1715.193      1523.813
# 3      3872.242       1350.757      4290.114       1446.737      4431.777
# 4      2383.849       4206.080      2187.993       2971.253      1188.533
#
#    Parea_ECG_V6  Parea_ECG_V8  Parea_ECG_V9  Parea_ECG_aVF  Parea_ECG_aVL  \
# ...

# %%
msno.heatmap(df_selected, figsize=(10,10));

# %%
del df_selected, df_columns, matching_columns

# %% [markdown]
# #### Pfwhm

# %%
df_columns = df.columns.tolist()
matching_columns = [s for s in df_columns if "Pfwhm" in s]
df_selected = data[matching_columns]
df_selected.head()
# Out:
#    Pfwhm_ECG_I  Pfwhm_ECG_II  Pfwhm_ECG_III  Pfwhm_ECG_V1  Pfwhm_ECG_V2  \
# 0     30.49997      57.02770       58.01223      34.05282      47.00230
# 1     66.00002      56.00309       62.00139      35.01057      38.08519
# 2     40.00084      29.00667       27.00890      34.03117      37.02539
# 3     48.00072      54.00824       58.00010      33.04055           NaN
# 4     24.38789     103.00880       76.00874      43.03947      58.02574
#
#    Pfwhm_ECG_V3  Pfwhm_ECG_V3R  Pfwhm_ECG_V4  Pfwhm_ECG_V4R  Pfwhm_ECG_V5  \
# 0      49.00052       44.18612      54.00165       46.01716      63.00000
# 1      39.00154            NaN      41.14600       57.00035      44.00013
# 2      38.00840       33.01305      38.00700            NaN      37.00476
# 3      55.00000       35.01414      54.00042       59.00004      54.00589
# 4      53.01237       44.01796      45.00424       42.00262      83.00031
#
#    Pfwhm_ECG_V6  Pfwhm_ECG_V8  Pfwhm_ECG_V9  Pfwhm_ECG_aVF  Pfwhm_ECG_aVL  \
# ...

# %%
msno.heatmap(df_selected, figsize=(10,10));

# %%
del df_selected, df_columns, matching_columns

# %% [markdown]
# #### QRS , PQ and P_LoffEon

# %%
qrs_pq_p = data[['Soggetti', 'QRS', 'PQ', 'P_LoffEon', 'AFclass']]
qrs_pq_p.head()
# Out:
#   Soggetti   QRS     PQ  P_LoffEon                       AFclass
# 0  01_2021   NaN  166.0      128.0  persistierend (>7 Tage, EKV)
# 1  01_2025  73.0  173.0      131.0  persistierend (>7 Tage, EKV)
# 2  01_2028  81.0  190.0      102.0  persistierend (>7 Tage, EKV)
# 3  01_2030  67.0  204.0      148.0  persistierend (>7 Tage, EKV)
# 4  01_2035  83.0  200.0      176.0  persistierend (>7 Tage, EKV)

# %%
corr = qrs_pq_p.corr()
plt.subplots(figsize=(4,4))
sns.heatmap(corr, square= True, annot = True)

# %%
qrs_null = set(qrs_pq_p[qrs_pq_p['QRS'].isnull()].Soggetti)
pq_null = set(qrs_pq_p[qrs_pq_p['PQ'].isnull()].Soggetti)
p_null = set(qrs_pq_p[qrs_pq_p['P_LoffEon'].isnull()].Soggetti)

# %%
plt.figure(figsize=(4, 4))
venn3([qrs_null, pq_null, p_null], set_labels=['QRS','PQ','P_LoffEon'])
plt.show()
# Out:
# /Users/refikcanmalli/anaconda3/envs/mdp/lib/python3.6/site-packages/matplotlib_venn/_venn3.py:117: UserWarning: Bad circle positioning
#   warnings.warn("Bad circle positioning")

# %% [markdown]
# ### Imputing

# %% [markdown]
# This part contains strategies for imputing the missing values. Each strategy should include the cleaned dataset as `pandas.DataFrame` and the name of the strategy. For each strategy **check** if all missing values are solved.

# %%
impute_strategies = {}

# %% [markdown]
# #### Mean and Zero Based Strategy

# %% [markdown]
# - Fill every numeric valued column with the mean value.
# - Fill every binary valued column with zero value.
# - Do not delete any row/sample.
#
# This is the simplest pipeline that we can follow for the handling the missing values. (Probably the worst idea...)

# %%
df.drop('Soggetti',axis=1, inplace=True, errors='ignore')

numerical_variables = df.columns[~categorical_variables_mask]

# print(categorical_variables)
# print(numerical_variables)

numerical_imputer = Imputer(missing_values="NaN",strategy="mean", copy=True)
numerical_imputer.fit(df[numerical_variables])
df_numerical_imputed_array = numerical_imputer.transform(df[numerical_variables])
df_numerical_imputed = pd.DataFrame(data=df_numerical_imputed_array,columns=numerical_variables)


categorical_data = {}
categorical_imputer = CategoricalImputer(missing_values="NaN")
for v in categorical_variables:
    categorical_imputer.fit(df[v])
    categorical_data[v] = categorical_imputer.transform(df[v])

df_categorical_imputed = pd.DataFrame(categorical_data,columns=categorical_variables)

df_imputed = pd.concat([df_numerical_imputed,df_categorical_imputed],axis=1)

assert(len(df_imputed.iloc[0] == 72))
assert(df_imputed.isnull().sum().sum() == 0)

# %%
df_imputed[numerical_variables] = StandardScaler().fit_transform(df_imputed[numerical_variables])
for v in categorical_variables:
    df_imputed[v] = LabelEncoder().fit_transform(df_imputed[v])
    
#df_imputed['patsex'] = StandardScaler().fit_transform(df_imputed['patsex'])

categorical_variables
# Out:
# Index(['patsex', 'AFclass'], dtype='object')

# %%
df_imputed.head()
# Out:
#          RR   QTm_old  sbjBeatConsidered  numRRaveraged        QR       QTn  \
# 0 -0.271566  0.543933          -0.170304      -0.239430  0.610630  1.049513
# 1  1.422095  1.081706          -0.736599      -0.555544 -0.598406 -0.037195
# 2 -0.362298  0.390283           0.414259       0.426073  1.517406  0.942636
# 3  0.272016 -0.659655          -0.152036      -0.106329  0.610630 -1.249010
# 4 -1.517695 -0.147490           1.967005       1.923455  0.308371  1.796885
#
#         QRS       IPG        PQ     PCpos         PCneg     PCdur    PCfwhm  \
# 0  0.000000 -0.105021 -0.638433 -0.122613  5.338572e-16  0.139509 -0.403083
# 1 -0.301537 -0.105021 -0.435886  0.624369  5.338572e-16  0.185923 -0.953765
# 2  0.220993 -0.105021  0.056015 -1.718318  2.501858e+00 -1.484981 -1.634698
# 3 -0.693435 -0.105021  0.461109  0.942793  5.338572e-16  0.742892 -0.274448
# 4  0.351626 -0.105021  0.345368 -0.310845  3.597495e-01  0.835720 -1.012693
#
# ...

# %%
impute_strategies.update({'meanzero':df_imputed})

# %% [markdown]
# #### Clear and Fancy Impute Strategy

# %% [markdown]
# 1. Drop the columns : `sbjBeatConsidered, numRRaveraged, Soggetti`
# 1. Drop 12 people related to `IPG` column
# 1. Drop Parea + Pdur missing People
# 1. Fill `PcNeg` column with zeros
# 1. Convert Categorical values to numbers
# 1. Seperate training data and labels
# 1. try to fill others with `fancyimpute`
# 1. Standart Scale the columns

# %%
data_e = data[data['IPG'] != 1]
data_e = data_e.drop('IPG', axis = 1);
data_e = data_e.drop('sbjBeatConsidered', axis = 1);
data_e = data_e.drop('numRRaveraged', axis = 1);
data_e = data_e.drop('Soggetti', axis = 1);
data_e.shape[0]
# Out:
# 1088

# %%
df_columns = df.columns.tolist()
matching_columns1 = [s for s in df_columns if "Parea" in s]
matching_columns2 = [s for s in df_columns if "Pdur" in s]
mc = matching_columns1 + matching_columns2
data_e = data_e.dropna(subset=mc)
del df_columns,matching_columns1,matching_columns2,mc
data_e.shape[0]
# Out:
# 977

# %%
data_e['PCneg'].fillna(0, inplace=True)

# %%
data_e['AFclass'].replace('persistierend (>7 Tage, EKV)', 1, inplace=True)
data_e['AFclass'].replace('paroxysmal', 0, inplace=True)

# %%
categorical_variables_mask = data_e.dtypes==object
categorical_variables = data_e.columns[categorical_variables_mask]
for v in categorical_variables:
    data_e[v] = LabelEncoder().fit_transform(data_e[v])
del categorical_variables_mask,categorical_variables

# %%
data_e = pd.DataFrame(data=MICE(n_imputations=100, impute_type='col', n_nearest_columns=5).complete(data_e.as_matrix()), columns=data_e.columns, index=data_e.index)
# Out:
# [MICE] Completing matrix with shape (977, 69)
# [MICE] Starting imputation round 1/110, elapsed time 0.003
# [MICE] Starting imputation round 2/110, elapsed time 0.017
# [MICE] Starting imputation round 3/110, elapsed time 0.035
# [MICE] Starting imputation round 4/110, elapsed time 0.052
# [MICE] Starting imputation round 5/110, elapsed time 0.082
# [MICE] Starting imputation round 6/110, elapsed time 0.106
# [MICE] Starting imputation round 7/110, elapsed time 0.136
# [MICE] Starting imputation round 8/110, elapsed time 0.168
# [MICE] Starting imputation round 9/110, elapsed time 0.210
# [MICE] Starting imputation round 10/110, elapsed time 0.231
# [MICE] Starting imputation round 11/110, elapsed time 0.266
# [MICE] Starting imputation round 12/110, elapsed time 0.322
# [MICE] Starting imputation round 13/110, elapsed time 0.360
# [MICE] Starting imputation round 14/110, elapsed time 0.398
# [MICE] Starting imputation round 15/110, elapsed time 0.420
# ...

# %%
data_e.to_csv("../data/cleandata.csv",encoding='utf-8', index=False)

# %%
y_df = data_e['AFclass'].copy()
X_df = data_e.drop('AFclass',axis=1, inplace=False)

# %%
num_columns = X_df.columns.tolist()
# num_columns.remove('Age')
num_columns.remove('patsex')
#X_df[num_columns] = StandardScaler().fit_transform(X_df[num_columns])

# %%
X_df.head()
# Out:
#             RR  QTm_old    QR         QTn        QRS     PQ      PCpos  \
# 0   958.864341    415.0  41.0  423.808354  79.424116  166.0  208.21120
# 1  1226.748954    436.0  29.0  393.648536  73.000000  173.0  260.65770
# 2   944.513423    409.0  50.0  420.842160  81.000000  190.0   96.17484
# 3  1044.842105    368.0  41.0  360.016567  67.000000  204.0  283.01460
# 4   761.765464    388.0  38.0  444.550483  83.000000  200.0  194.99520
#
#        PCneg  PCdur    PCfwhm     PCarea  P_LoffEon  Pdur16mean  Pdur16median  \
# 0   0.000000  122.0  52.10900  12260.060      128.0    116.7500         122.0
# 1   0.000000  123.0  44.01226  13517.650      131.0    122.5000         122.5
# 2  -1.426192   87.0  34.00043   3159.255      102.0     83.8125          83.5
# 3   0.000000  135.0  54.00034  17693.560      148.0    133.4375         135.5
# 4 -58.447420  137.0  43.14584   9944.122      176.0    145.8750         141.0
#
# ...

# %%
num_missing = X_df.shape[0] - X_df.count()
assert(num_missing.sum() == 0)
del num_missing

# %%
X = X_df.values
y = y_df.values
print(X.shape)
print(y.shape)
# Out:
# (977, 68)
# (977,)

# %% [markdown]
# ### Testing

# %%
random_state = np.random.RandomState(0)

# %% [markdown]
# #### Simple Single Methods

# %% [markdown]
# ##### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model = model.fit(X, y)
model.score(X, y)
# Out:
# 0.7195496417604913

# %%
column_names = X_df.columns
temp = pd.DataFrame(list(zip(column_names, np.transpose(model.coef_))))
temp.reindex(temp[1].abs().sort_values().index[::-1])
# Out:
#                 0                         1
# 40  Parea_ECG_V3R      [0.4503568266647995]
# 47  Parea_ECG_aVF    [-0.43614470329286004]
# 10         PCarea     [-0.4186991762827865]
# 41   Parea_ECG_V4       [0.366798171407411]
# 35   Parea_ECG_II      [0.3559080587547108]
# 43   Parea_ECG_V5     [-0.3438114466331138]
# 1         QTm_old      [0.3174107073871424]
# 8           PCdur     [-0.2797931364528834]
# 65  Pfwhm_ECG_aVR    [-0.25944089032151973]
# 36  Parea_ECG_III     [0.25348386718056265]
# 21    Pdur_ECG_V1    [-0.25164387189407283]
# 11      P_LoffEon     [0.25010192412838717]
# 23    Pdur_ECG_V3     [-0.2494335591374451]
# 15      Pdur16max     [0.24678349761968002]
# 66         patsex    [-0.24549032187352557]
# 67            Age    [-0.22684248533344747]
# 28    Pdur_ECG_V6     [0.22476752814463605]
# 42  Parea_ECG_V4R    [-0.22336222992813323]
# 31   Pdur_ECG_aVF     [0.22045795703777787]
# 46   Parea_ECG_V9     [-0.2187484462829325]
# ...

# %% [markdown]
# ##### SVM

# %%
model = svm.SVC(kernel='rbf',C=1, probability=True, class_weight={0: 0.3,1:0.7},
                     random_state=random_state)
model = model.fit(X, y)
model.score(X, y)
# Out:
# 0.6786079836233367

# %% [markdown]
# #### Cross validation and ROC curve method

# %%
cv = model_selection.StratifiedKFold(n_splits=10, shuffle=True,random_state=random_state)
classifier = svm.SVC(kernel='rbf',C=1, probability=True,
                     random_state=random_state)

# %%
tprs = []
aucs = []
mean_fpr = np.linspace(0, 1, 100)
fig = plt.figure(figsize = (10,10))
i = 0
for train, test in cv.split(X, y):
    probas_ = classifier.fit(X[train], y[train]).predict_proba(X[test])
    # Compute ROC curve and area the curve
    fpr, tpr, thresholds = roc_curve(y[test], probas_[:, 1])
    tprs.append(interp(mean_fpr, fpr, tpr))
    tprs[-1][0] = 0.0
    roc_auc = auc(fpr, tpr)
    aucs.append(roc_auc)
    plt.plot(fpr, tpr, lw=1, alpha=0.3,
                 label='ROC fold %d (AUC = %0.2f)' % (i, roc_auc))

    i += 1
plt.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',
             label='Random Luck', alpha=.8)

mean_tpr = np.mean(tprs, axis=0)
mean_tpr[-1] = 1.0
mean_auc = auc(mean_fpr, mean_tpr)
std_auc = np.std(aucs)
plt.plot(mean_fpr, mean_tpr, color='b',
             label=r'Mean ROC (AUC = %0.2f $\pm$ %0.2f)' % (mean_auc, std_auc),
             lw=2, alpha=.8)

std_tpr = np.std(tprs, axis=0)
tprs_upper = np.minimum(mean_tpr + std_tpr, 1)
tprs_lower = np.maximum(mean_tpr - std_tpr, 0)
plt.fill_between(mean_fpr, tprs_lower, tprs_upper, color='grey', alpha=.2,
                     label=r'$\pm$ 1 std. dev.')

plt.xlim([-0.05, 1.05])
plt.ylim([-0.05, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# #### Partial Dependence Plot

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble.partial_dependence import plot_partial_dependence
from sklearn.ensemble.partial_dependence import partial_dependence
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import cohen_kappa_score, make_scorer
from imblearn.over_sampling import SMOTE, ADASYN
from imblearn.pipeline import Pipeline

# %%
kappa_scorer = make_scorer(cohen_kappa_score)
param_grid={'clf__n_estimators': [50, 100, 200,],'clf__max_depth': [5,7,9],'clf__learning_rate': [0.1,0.5,0.7]}
gbc = GradientBoostingClassifier(random_state=1)
plist = []
plist.append(('balancer', SMOTE(random_state=1)))
plist.append(('clf', gbc))
pipeline = Pipeline(plist)
grid = GridSearchCV(pipeline, param_grid=param_grid, scoring='accuracy',n_jobs=-1,cv=10)

# %%
grid.fit(X, y)
# Out:
# GridSearchCV(cv=None, error_score='raise',
#        estimator=Pipeline(memory=None,
#      steps=[('balancer', SMOTE(k=None, k_neighbors=5, kind='regular', m=None, m_neighbors=10, n_jobs=1,
#    out_step=0.5, random_state=1, ratio='auto', svm_estimator=None)), ('clf', GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=...         presort='auto', random_state=1, subsample=1.0, verbose=0,
#               warm_start=False))]),
#        fit_params=None, iid=True, n_jobs=-1,
#        param_grid={'clf__n_estimators': [50, 100, 200, 300], 'clf__max_depth': [3, 5, 7, 9], 'clf__learning_rate': [0.1, 0.01, 0.5]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='accuracy', verbose=0)

# %%
clf = grid.best_estimator_.steps[-1][1]
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'clf__learning_rate': 0.5, 'clf__max_depth': 7, 'clf__n_estimators': 50}
# 0.6458546571136131

# %%
clf.feature_importances_
# Out:
# array([0.02009911, 0.02443775, 0.02219606, 0.0250261 , 0.02410982,
#        0.02315115, 0.01471445, 0.00548602, 0.00259577, 0.01249982,
#        0.00980313, 0.00510129, 0.00244055, 0.00325725, 0.00355479,
#        0.00503185, 0.02462615, 0.01830535, 0.00924771, 0.01042051,
#        0.007975  , 0.00922031, 0.01428548, 0.00717701, 0.0090883 ,
#        0.01037732, 0.00584452, 0.0077861 , 0.00662167, 0.00788143,
#        0.00788876, 0.00355799, 0.00800076, 0.00612393, 0.02151566,
#        0.01256538, 0.0172633 , 0.01575991, 0.02127656, 0.01470914,
#        0.01927465, 0.01494967, 0.02359366, 0.01539516, 0.01448306,
#        0.01878356, 0.02133027, 0.01193488, 0.03113804, 0.01533809,
#        0.01842076, 0.01379714, 0.01363652, 0.0250913 , 0.01724413,
#        0.02240131, 0.02572417, 0.01634359, 0.01792143, 0.01236258,
#        0.01164583, 0.01363599, 0.01850143, 0.01663416, 0.01866048,
#        0.02366311, 0.01619849, 0.03087338])

# %%
importances = clf.feature_importances_
indices = np.argsort(importances)[::-1]

# Print the feature ranking
print("Feature ranking:")

for f in range(X.shape[1]):
    print("%d. feature %d - %s (%f)" % (f + 1, indices[f],X_df.columns[indices[f]], importances[indices[f]]))

# Plot the feature importances of the forest
plt.figure()
plt.title("Feature importances")
plt.bar(range(X.shape[1]), importances[indices],
       color="r", align="center")
plt.xticks(range(X.shape[1]), indices)
plt.xlim([-1, X.shape[1]])
plt.show()
# Out:
# Feature ranking:
# 1. feature 48 - Parea_ECG_aVL (0.031138)
# 2. feature 67 - Age (0.030873)
# 3. feature 56 - Pfwhm_ECG_V3R (0.025724)
# 4. feature 53 - Pfwhm_ECG_V1 (0.025091)
# 5. feature 3 - QTn (0.025026)
# 6. feature 16 - Pdur16std (0.024626)
# 7. feature 1 - QTm_old (0.024438)
# 8. feature 4 - QRS (0.024110)
# 9. feature 65 - Pfwhm_ECG_aVR (0.023663)
# 10. feature 42 - Parea_ECG_V4R (0.023594)
# 11. feature 5 - PQ (0.023151)
# 12. feature 55 - Pfwhm_ECG_V3 (0.022401)
# 13. feature 2 - QR (0.022196)
# 14. feature 34 - Parea_ECG_I (0.021516)
# 15. feature 46 - Parea_ECG_V9 (0.021330)
# 16. feature 38 - Parea_ECG_V2 (0.021277)
# 17. feature 0 - RR (0.020099)
# 18. feature 40 - Parea_ECG_V3R (0.019275)
# 19. feature 45 - Parea_ECG_V8 (0.018784)
# 20. feature 64 - Pfwhm_ECG_aVL (0.018660)
# 21. feature 62 - Pfwhm_ECG_V9 (0.018501)
# 22. feature 50 - Pfwhm_ECG_I (0.018421)
# 23. feature 17 - Pdur16iqr (0.018305)
# 24. feature 58 - Pfwhm_ECG_V4R (0.017921)
# ...

# %%
# features = [67, 66]
# fig, axs = plot_partial_dependence(clf, X, features,
#                                        feature_names=X_df.columns,
#                                        n_jobs=3, grid_resolution=50)
# plt.subplots_adjust(top=0.9)  # tight_layout causes overlap with suptitle

# %%
from skater.core.explanations import Interpretation
from skater.model import InMemoryModel
i = Interpretation(X, feature_names=X_df.columns)
model = InMemoryModel(clf.predict_proba, examples = X)
features = [X_df.columns[48], X_df.columns[3], X_df.columns[67], X_df.columns[66]]
i.partial_dependence.plot_partial_dependence(features,
                                            model)
# Out:
# 2018-05-14 16:09:25,108 - skater.core.explanations - WARNING - Progress bars slow down runs by 10-20%. For slightly
# faster runs, do progress_bar=False
# [30/30] grid cells ████████████████████ Time elapsed: 4 seconds
# 2018-05-14 16:09:29,572 - skater.core.explanations - WARNING - Progress bars slow down runs by 10-20%. For slightly
# faster runs, do progress_bar=False
# [30/30] grid cells ████████████████████ Time elapsed: 4 seconds
# 2018-05-14 16:09:34,364 - skater.core.explanations - WARNING - Progress bars slow down runs by 10-20%. For slightly
# faster runs, do progress_bar=False
# [24/24] grid cells ████████████████████ Time elapsed: 3 seconds
# 2018-05-14 16:09:37,807 - skater.core.explanations - WARNING - Progress bars slow down runs by 10-20%. For slightly
# faster runs, do progress_bar=False
# [2/2] grid cells ████████████████████ Time elapsed: 0 seconds
# [[<Figure size 1152x720 with 1 Axes>,
# ...
#  [<Figure size 1152x720 with 1 Axes>,
# ...

# %% [markdown]
# #### Feature Elimination/Selection

# %%
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier,ExtraTreesClassifier,AdaBoostClassifier

et = ExtraTreesClassifier(max_depth=8,n_estimators=1000,min_samples_leaf=5, random_state=42)

# %%
# The "accuracy" scoring is proportional to the number of correct
# classifications


rfecv = RFECV(estimator=et, step=1, cv=10,n_jobs=-1,verbose=1,
              scoring='roc_auc')
rfecv.fit(X_df, y_df)

print("Optimal number of features : %d" % rfecv.n_features_)

# Plot number of features VS. cross-validation scores
plt.figure()
plt.xlabel("Number of features selected")
plt.ylabel("Cross validation score (nb of correct classifications)")
plt.plot(range(1, len(rfecv.grid_scores_) + 1), rfecv.grid_scores_)
plt.show()
# Out:
# Fitting estimator with 68 features.
# Fitting estimator with 68 features.
# Fitting estimator with 68 features.
# Fitting estimator with 68 features.
# Fitting estimator with 67 features.
# Fitting estimator with 67 features.
# Fitting estimator with 67 features.
# Fitting estimator with 67 features.
# Fitting estimator with 66 features.
# Fitting estimator with 66 features.
# Fitting estimator with 66 features.
# Fitting estimator with 66 features.
# Fitting estimator with 65 features.
# Fitting estimator with 65 features.
# Fitting estimator with 65 features.
# Fitting estimator with 65 features.
# Fitting estimator with 64 features.
# Fitting estimator with 64 features.
# Fitting estimator with 64 features.
# Fitting estimator with 64 features.
# Fitting estimator with 63 features.
# Fitting estimator with 63 features.
# Fitting estimator with 63 features.
# Fitting estimator with 63 features.
# Fitting estimator with 62 features.
# Fitting estimator with 62 features.
# ...

# %%
np.max(rfecv.grid_scores_)
# Out:
# 0.5946990852190659

# %% [markdown]
# # References
